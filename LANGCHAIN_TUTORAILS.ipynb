# %% [markdown]
# <a href="https://colab.research.google.com/github/Manikanta-23-ai/LANGCHAIN-LEARNING/blob/main/LANGCHAIN_TUTORAILS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q langchain langchain-openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.1/125.1 kB 4.1 MB/s eta 0:00:00

# %%
from langchain_openai import ChatOpenAI

print("LangChain is ready!")
# Out:
# LangChain is ready!

# %%
import os
import getpass

os.environ["OPENAI"] = getpass.getpass(
    "Enter key "
)
# Out:
# Enter key ··········

# %%
model = ChatOpenAI(
    model="gpt-4.1-mini"
)

# %%
# !pip install -q langchain_llms
# Out:
# ERROR: Could not find a version that satisfies the requirement langchain_llms (from versions: none)
# ERROR: No matching distribution found for langchain_llms

# %%
pip list
# Out:
# Package                               Version
# ------------------------------------- -------------------
# absl-py                               1.4.0
# accelerate                            1.14.0
# access                                1.1.10.post3
# affine                                3.0.0
# aiofiles                              25.1.0
# aiohappyeyeballs                      2.7.1
# aiohttp                               3.14.3
# aiosignal                             1.4.0
# aiosqlite                             0.22.1
# alabaster                             1.0.0
# albucore                              0.0.24
# albumentations                        2.0.8
# ale-py                                0.12.1
# altair                                5.5.0
# annotated-doc                         0.0.5
# annotated-types                       0.8.0
# antlr4-python3-runtime                4.9.3
# anyio                                 4.14.2
# anywidget                             0.9.21
# ...

# %%
# !pip install -q -U langchain langchain-google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.0/148.0 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.6/81.6 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 34.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.5/571.5 kB 27.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.7/259.7 kB 18.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.57.0 which is incompatible.

# %%
# !pip install -q -U langchain langchain-google-genai

# %%
import os
from getpass import getpass

os.environ["GOOGLE_API_KEY"] = getpass("Enter your Gemini API key: ")
# Out:
# Enter your Gemini API key: ··········

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
model = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash",
    temperature=0
)

# %%
response = model.invoke("What is LangChain?")
print(response.content)
# Out:
# /usr/local/lib/python3.13/dist-packages/langchain_google_genai/chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# ...

# %%
# !pip langchain_core.prompts
# Out:
# ERROR: unknown command "langchain_core.prompts"

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
response = chain.invoke({
    "topic": "Langgraph"
})

print(response.content)
# Out:
# /usr/local/lib/python3.13/dist-packages/langchain_google_genai/chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# ...

# %%
prompt = ChatPromptTemplate.from_template("""
You are an expert teacher.

Explain {topic} to a beginner.

Include:
1. Definition
2. Why it is important
3. Simple example
4. Real-world use case
5. Short summary
""")

# %%
chain = prompt | model

# %%
response = chain.invoke({
    "topic": "Artificial Intelligence"
})

print(response.content)
# Out:
# /usr/local/lib/python3.13/dist-packages/langchain_google_genai/chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# ...

# %%
def ask_ai(topic):
    response = chain.invoke({
        "topic": topic
    })
    return response.content

# %%
print(ask_ai("what is ai business"))
# Out:
# /usr/local/lib/python3.13/dist-packages/langchain_google_genai/chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# ...

# %%
print(ask_ai("what is ai voiceagent"))
# Out:
# /usr/local/lib/python3.13/dist-packages/langchain_google_genai/chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# ...

# %%
print(ask_ai("what is ai crewai"))
# Out:
# /usr/local/lib/python3.13/dist-packages/langchain_google_genai/chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# ...

# %%
print(ask_ai("what is ai ai agents"))
# Out:
# /usr/local/lib/python3.13/dist-packages/langchain_google_genai/chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# ...

# %%
print(ask_ai("what is ai freelancing"))

# %%
print(ask_ai("what is ai business"))
# Out:
# /usr/local/lib/python3.13/dist-packages/langchain_google_genai/chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# ...

# %%
print(ask_ai("what is ai ai agency"))
# Out:
# /usr/local/lib/python3.13/dist-packages/langchain_google_genai/chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# ...

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# %%
parser = StrOutputParser()

# %%
StrOutputParser()
# Out:
# StrOutputParser()

# %%
chain = prompt | model | StrOutputParser()

response = chain.invoke({
    "topic": "LangChain"
})

print(response)
# Out:
# /usr/local/lib/python3.13/dist-packages/langchain_google_genai/chat_models.py:3908: UserWarning: Model 'gemini-3.6-flash' uses fixed sampling defaults; the sampling parameter(s) temperature will be ignored.
#   request = self._build_request_config(
# Welcome! As your teacher today, I’m going to break down **LangChain** into simple, bite-sized concepts. No heavy technical jargon required!
#
# ---
#
# ### 1. Definition
#
# **LangChain** is an open-source software framework that acts like a **bridge (or glue)** between Artificial Intelligence (like ChatGPT) and external resources like your documents, databases, and the internet.
#
# *   **Think of it like Lego blocks for AI:** Large Language Models (LLMs) like ChatGPT are super-smart brains, but on their own, they are trapped in a box. LangChain gives developers the Lego bricks to build full applications around that brain—connecting it to hands, tools, and memory.
#
# ---
#
# ### 2. Why It Is Important
#
# ...

# %%
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 42.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 39.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 5.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.57.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# ...

# %%
# !pip install -q -U pypdf
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.1/385.1 kB 8.4 MB/s eta 0:00:00

# %%
from langchain_community.document_loaders import PyPDFLoader
# Out:
# /tmp/ipykernel_1139/4175148793.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
loader = PyPDFLoader("")

documents = loader.load()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1139/1303470153.py in <cell line: 0>()
# ----> 1 loader = PyPDFLoader("")
#       2
#       3 documents = loader.load()
#
# /usr/local/lib/python3.13/dist-packages/langchain_community/document_loaders/pdf.py in __init__(self, file_path, password, headers, extract_images, mode, images_parser, images_inner_format, pages_delimiter, extraction_mode, extraction_kwargs)
#     279             `aload` methods to retrieve parsed documents with content and metadata.
#     280         """
# --> 281         super().__init__(file_path, headers=headers)
#     282         self.parser = PyPDFParser(
#     283             password=password,
#
# /usr/local/lib/python3.13/dist-packages/langchain_community/document_loaders/pdf.py in __init__(self, file_path, headers)
#     138                 self.file_path = str(temp_pdf)
# ...
